# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os

sys.path.insert(0, os.path.abspath(os.path.join('..')))
# %matplotlib inline

from src.visualization import show_series_stl, show_acf_pacf

# %%
df = pd.read_csv('../data/processed/ZK 68, (48-1, 48-air), 27.11.20-15.12.25.csv')
df.index = df['Дата']
df = df.drop(columns=['Дата'])
df
# Out:
#              Год  Месяц  День  48-1 (0)  48-1 (0,5)  48-1 (1)  48-1 (1,5)  \
# Дата
# 2020-11-27  2020     11    27     -5.47       -2.03     -0.22        0.02
# 2020-11-28  2020     11    28     -7.20       -2.30     -0.25        0.02
# 2020-11-29  2020     11    29     -8.85       -2.95     -0.34        0.02
# 2020-11-30  2020     11    30     -6.07       -3.35     -0.47        0.02
# 2020-12-01  2020     12     1     -4.29       -3.04     -0.54        0.02
# ...          ...    ...   ...       ...         ...       ...         ...
# 2025-12-11  2025     12    11     -8.95       -5.14     -2.57       -0.52
# 2025-12-12  2025     12    12     -9.36       -5.32     -2.68       -0.60
# 2025-12-13  2025     12    13     -9.14       -5.53     -2.81       -0.71
# 2025-12-14  2025     12    14     -9.85       -5.68     -2.98       -0.84
# 2025-12-15  2025     12    15    -10.80       -5.87     -3.10       -0.93
#
#             48-1 (2)  48-1 (2,5)  48-1 (3)  ...  48-1 (4)  48-1 (4,5)  \
# ...

# %% [markdown]
# STL Decomposition

# %%
show_series_stl(df['48-Воздух (0)'])
show_series_stl(df['48-1 (0)'])
show_series_stl(df['48-1 (2,5)'])
show_series_stl(df['48-1 (5)'])
show_series_stl(df['48-1 (10)'])

# %% [markdown]
# ACF и PACF

# %%
show_acf_pacf(df['48-Воздух (0)'], lags = 20)
show_acf_pacf(df['48-1 (0)'], lags = 20)
show_acf_pacf(df['48-1 (2,5)'], lags = 20)
show_acf_pacf(df['48-1 (5)'], lags = 20)
show_acf_pacf(df['48-1 (10)'], lags = 20)
