# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../data/processed/ZK 68, (48-1, 48-air), 27.11.20-15.12.25.csv')
df
# Out:
#             Дата   Год  Месяц  День  48-1 (0)  48-1 (0,5)  48-1 (1)  \
# 0     2020-11-27  2020     11    27     -5.47       -2.03     -0.22
# 1     2020-11-28  2020     11    28     -7.20       -2.30     -0.25
# 2     2020-11-29  2020     11    29     -8.85       -2.95     -0.34
# 3     2020-11-30  2020     11    30     -6.07       -3.35     -0.47
# 4     2020-12-01  2020     12     1     -4.29       -3.04     -0.54
# ...          ...   ...    ...   ...       ...         ...       ...
# 1840  2025-12-11  2025     12    11     -8.95       -5.14     -2.57
# 1841  2025-12-12  2025     12    12     -9.36       -5.32     -2.68
# 1842  2025-12-13  2025     12    13     -9.14       -5.53     -2.81
# 1843  2025-12-14  2025     12    14     -9.85       -5.68     -2.98
# 1844  2025-12-15  2025     12    15    -10.80       -5.87     -3.10
#
#       48-1 (1,5)  48-1 (2)  48-1 (2,5)  ...  48-1 (4)  48-1 (4,5)  48-1 (5)  \
# 0           0.02      0.02        0.02  ...     -0.36       -0.41     -0.52
# 1           0.02      0.02        0.02  ...     -0.36       -0.41     -0.53
# 2           0.02      0.02        0.02  ...     -0.35       -0.41     -0.54
# 3           0.02      0.02        0.02  ...     -0.37       -0.41     -0.54
# 4           0.02      0.02        0.02  ...     -0.38       -0.42     -0.55
# ...          ...       ...         ...  ...       ...         ...       ...
# 1840       -0.52     -0.09       -0.05  ...     -1.35       -1.55     -1.77
# 1841       -0.60     -0.09       -0.05  ...     -1.35       -1.57     -1.80
# 1842       -0.71     -0.09       -0.05  ...     -1.38       -1.61     -1.82
# 1843       -0.84     -0.09       -0.05  ...     -1.42       -1.63     -1.88
# 1844       -0.93     -0.09       -0.05  ...     -1.46       -1.68     -1.87
#
#       48-1 (6)  48-1 (7)  48-1 (8)  48-1 (9)  48-1 (10)  48-1 (11)  \
# 0        -0.54     -0.54     -0.52     -0.36      -0.28      -0.17
# 1        -0.54     -0.54     -0.51     -0.36      -0.28      -0.18
# 2        -0.54     -0.54     -0.51     -0.35      -0.28      -0.18
# 3        -0.55     -0.54     -0.49     -0.39      -0.28      -0.20
# 4        -0.56     -0.54     -0.50     -0.39      -0.28      -0.19
# ...        ...       ...       ...       ...        ...        ...
# 1840     -1.92     -1.93     -1.75     -1.48      -1.17      -1.00
# 1841     -1.92     -1.95     -1.80     -1.50      -1.19      -1.00
# 1842     -1.96     -1.98     -1.81     -1.51      -1.21      -1.01
# 1843     -1.99     -2.00     -1.82     -1.54      -1.22      -1.02
# 1844     -2.03     -2.01     -1.87     -1.54      -1.22      -1.03
#
#       48-Воздух (0)
# 0            -11.93
# 1             -8.96
# 2             -6.54
# 3             -4.57
# 4             -3.78
# ...             ...
# 1840          -6.99
# 1841          -8.15
# 1842          -8.01
# 1843         -10.16
# 1844         -10.64
#
# [1845 rows x 22 columns]

# %%
from src.visualization import show_series_stl

# построение STL
df.index = df['Дата']
df = df.drop(columns=['Дата'])

show_series_stl(df['48-Воздух (0)'])
show_series_stl(df['48-1 (0)'])
show_series_stl(df['48-1 (2,5)'])
show_series_stl(df['48-1 (5)'])
show_series_stl(df['48-1 (10)'])
